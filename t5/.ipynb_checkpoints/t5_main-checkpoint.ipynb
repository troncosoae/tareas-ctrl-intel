# %% [markdown]
# # imports

# %%
import pandas as pd
import requests
from scipy import stats
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %% [markdown]
# # get data

# %%
API_KEY = "3856b633126e4a27b2e45516c9290395"
URL = f"https://api.covidactnow.org/v2/states.timeseries.csv?apiKey={API_KEY}"
PATH = "data/states_series.csv"

r = requests.get(URL)

with open(PATH, 'w') as f:
    f.write(r.text)

# %% [markdown]
# # import data

# %%
data_all = pd.read_csv(PATH)

# %% [markdown]
# # process data

# %%
# get only from Colorado
state = 'CO'
data_all = data_all[data_all['state'] == state]
# get dates in range 01/03/2020 to 26/09/2021
date_start = '2020-03-01'
date_stop = '2021-09-26'
data = data_all[(data_all['date']>=date_start) & (data_all['date']<=date_stop)]
# conseguir data test: 27/09/2021 to 04/10/2021
date_start_test = '2021-09-25'
date_stop_test = '2021-10-04'
data_test = data_all[(data_all['date']>=date_start_test) & (data_all['date']<=date_stop_test)]
data
data.columns
# Out:
# Index(['date', 'country', 'state', 'county', 'fips', 'lat', 'long',
#        'locationId', 'actuals.cases', 'actuals.deaths',
#        'actuals.positiveTests', 'actuals.negativeTests',
#        'actuals.contactTracers', 'actuals.hospitalBeds.capacity',
#        'actuals.hospitalBeds.currentUsageTotal',
#        'actuals.hospitalBeds.currentUsageCovid', 'unused1',
#        'actuals.icuBeds.capacity', 'actuals.icuBeds.currentUsageTotal',
#        'actuals.icuBeds.currentUsageCovid', 'unused2', 'actuals.newCases',
#        'actuals.vaccinesDistributed', 'actuals.vaccinationsInitiated',
#        'actuals.vaccinationsCompleted', 'metrics.testPositivityRatio',
#        'metrics.testPositivityRatioDetails', 'metrics.caseDensity',
#        'metrics.contactTracerCapacityRatio', 'metrics.infectionRate',
#        'metrics.infectionRateCI90', 'unused3', 'unused4',
#        'metrics.icuCapacityRatio', 'riskLevels.overall',
#        'metrics.vaccinationsInitiatedRatio',
#        'metrics.vaccinationsCompletedRatio', 'actuals.newDeaths',
#        'actuals.vaccinesAdministered', 'riskLevels.caseDensity',
#        'cdcTransmissionLevel'],
#       dtype='object')

# %% [markdown]
# # plot data

# %%
data.plot(x='date', y='actuals.newCases')
# Out:
# <AxesSubplot:xlabel='date'>

# %%
data['actuals.newCases'].plot.hist(bins=100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# # prepare data

# %%
keys = [
    'actuals.newCases',
    'actuals.cases',
    'actuals.newDeaths',
    'actuals.deaths',
    'actuals.positiveTests',
    'actuals.negativeTests',
    'actuals.vaccinesDistributed',
    'actuals.vaccinationsInitiated',
    'actuals.vaccinationsCompleted',
    'metrics.testPositivityRatio',
    'metrics.infectionRate',
#     'riskLevels.caseDensity', 
#     'cdcTransmissionLevel'
]
# get certain cols
data = data[keys]
data_test = data_test[keys]
# apply window
window_size = 7
data = data.rolling(window_size, win_type='gaussian').sum(std=3)
replace nans for 0s
data = data.fillna(0)
data_test = data_test.fillna(0)
# normalize
data_mean = data.mean()
data_std = data.std()
data_std['actuals.newCases'] = data_std['actuals.newCases']*0.05
data_norm = (data-data_mean)/data_std

data_columns = data_norm.columns
torch_data = torch.tensor(data_norm.values)

# %%
data
# Out:
#       actuals.newCases  actuals.cases  actuals.newDeaths  actuals.deaths  \
# 3123               0.0            0.0                0.0             0.0
# 3124               0.0            0.0                0.0             0.0
# 3125               0.0            0.0                0.0             0.0
# 3126               0.0            0.0                0.0             0.0
# 3127               0.0            2.0                0.0             0.0
# ...                ...            ...                ...             ...
# 3693            1311.0       660023.0               14.0          7619.0
# 3694            2428.0       662451.0               15.0          7634.0
# 3695            1559.0       664010.0               14.0          7648.0
# 3696             386.0       664396.0                1.0          7649.0
# 3697             386.0       664782.0               13.0          7662.0
#
#       actuals.positiveTests  actuals.negativeTests  \
# 3123                    0.0                    1.0
# 3124                    0.0                    9.0
# 3125                    0.0                   24.0
# 3126                    0.0                   57.0
# 3127                    0.0                   84.0
# ...                     ...                    ...
# 3693               662359.0              9246858.0
# 3694               664468.0              9277531.0
# 3695               666735.0              9313803.0
# 3696               668384.0              9333946.0
# 3697               669566.0              9347759.0
#
#       actuals.vaccinesDistributed  actuals.vaccinationsInitiated  \
# 3123                          0.0                            0.0
# 3124                          0.0                            0.0
# 3125                          0.0                            0.0
# 3126                          0.0                            0.0
# 3127                          0.0                            0.0
# ...                           ...                            ...
# 3693                    8072555.0                      3746371.0
# 3694                    8082735.0                      3750533.0
# 3695                    8094315.0                      3755485.0
# 3696                    8109865.0                      3759587.0
# 3697                    8109725.0                      3764748.0
#
#       actuals.vaccinationsCompleted  metrics.testPositivityRatio  \
# 3123                            0.0                        0.000
# 3124                            0.0                        0.000
# 3125                            0.0                        0.000
# 3126                            0.0                        0.000
# 3127                            0.0                        0.000
# ...                             ...                          ...
# 3693                      3384603.0                        0.070
# 3694                      3389188.0                        0.069
# 3695                      3394941.0                        0.068
# 3696                      3399977.0                        0.067
# 3697                      3405927.0                        0.068
#
#       metrics.infectionRate
# 3123                   0.00
# 3124                   0.00
# 3125                   0.00
# 3126                   0.00
# 3127                   0.00
# ...                     ...
# 3693                   0.99
# 3694                   0.99
# 3695                   1.00
# 3696                   1.01
# 3697                   1.01
#
# [575 rows x 11 columns]

# %%
INPUT_DIM = len(keys)
N = torch_data.shape[0] - 1
X = torch.zeros(N, INPUT_DIM)
Y = torch.zeros(N, INPUT_DIM)

for i in range(N):
    X[i,:] = torch_data[i,:]
    Y[i,:] = torch_data[i+1,:]

# for i in range(N):
#     X[i,:,:] = torch_data[i:i+MEM_SHIFTS,:]
#     Y[i,:] = torch_data[i+MEM_SHIFTS,:]

# %% [markdown]
# # model

# %%
class LSTMcovid(nn.Module):
    def __init__(self, input_dim, hidden_dim):
        super(LSTMcovid, self).__init__()
        self.lstm = nn.LSTM(input_dim, hidden_dim)
        self.hidden2vals = nn.Linear(hidden_dim, input_dim)
    
    def forward(self, sequence):
        lstm_out, hidden = self.lstm(sequence)
        vals = self.hidden2vals(lstm_out)
        return vals
    
    def suit4model(self, tsr):
        return tsr.unsqueeze(1).float()

# %%
HIDDEN_DIM = 20
model = LSTMcovid(INPUT_DIM, HIDDEN_DIM)

# %% [markdown]
# # run model

# %%
with torch.no_grad():
    X2 = model.suit4model(X)
    Y_preds = model(X2)
    print(Y_preds, Y_preds.shape)
    print(Y, Y.shape)
# Out:
# tensor([[[ 0.0531, -0.1740, -0.1381,  ..., -0.1921,  0.0357,  0.0616]],
#
#         [[ 0.0199, -0.2176, -0.1494,  ..., -0.2073,  0.0056,  0.1092]],
#
#         [[ 0.0167, -0.2323, -0.1410,  ..., -0.2154, -0.0057,  0.1110]],
#
#         ...,
#
#         [[ 0.0794,  0.4612,  0.0115,  ...,  0.0130,  0.0824,  0.0087]],
#
#         [[ 0.0540,  0.5063,  0.0065,  ..., -0.0268,  0.0400, -0.0368]],
#
#         [[-0.0144, -0.0777, -0.0970,  ..., -0.1242, -0.0143,  0.0961]]]) torch.Size([574, 1, 11])
# tensor([[-1.9314e+01, -1.1988e+00, -7.3756e-01,  ..., -6.8714e-01,
#          -1.9661e+00, -5.0908e+00],
#         [-1.9314e+01, -1.1988e+00, -7.3756e-01,  ..., -6.8714e-01,
#          -1.9661e+00, -5.0908e+00],
#         [-1.9314e+01, -1.1988e+00, -7.3756e-01,  ..., -6.8714e-01,
#          -1.9661e+00, -5.0908e+00],
#         ...,
#         [ 6.8166e+00,  1.6405e+00,  6.2407e-02,  ...,  1.9995e+00,
#           1.9579e-01, -1.7087e-01],
#         [-1.2844e+01,  1.6422e+00, -6.8042e-01,  ...,  2.0035e+00,
#           1.6400e-01, -1.2167e-01],
#         [-1.2844e+01,  1.6438e+00,  5.2668e-03,  ...,  2.0082e+00,
#           1.9579e-01, -1.2167e-01]]) torch.Size([574, 11])

# %% [markdown]
# # train model

# %%
EPOCHS = 20

loss_function = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.1)

for epoch in range(EPOCHS):
    print(f'epoch: {epoch}')
    model.zero_grad()

    suited_X = model.suit4model(X)
    Y_preds = model(suited_X).squeeze()
    print(Y_preds, Y_preds.shape)
    print(Y, Y.shape)
#     Y = Y.long()
        
    
    loss = loss_function(Y_preds, Y)
    loss.backward()
    optimizer.step()
# Out:
# epoch: 0
# tensor([[ 0.0531, -0.1740, -0.1381,  ..., -0.1921,  0.0357,  0.0616],
#         [ 0.0199, -0.2176, -0.1494,  ..., -0.2073,  0.0056,  0.1092],
#         [ 0.0167, -0.2323, -0.1410,  ..., -0.2154, -0.0057,  0.1110],
#         ...,
#         [ 0.0794,  0.4612,  0.0115,  ...,  0.0130,  0.0824,  0.0087],
#         [ 0.0540,  0.5063,  0.0065,  ..., -0.0268,  0.0400, -0.0368],
#         [-0.0144, -0.0777, -0.0970,  ..., -0.1242, -0.0143,  0.0961]],
#        grad_fn=<SqueezeBackward0>) torch.Size([574, 11])
# tensor([[-1.9314e+01, -1.1988e+00, -7.3756e-01,  ..., -6.8714e-01,
#          -1.9661e+00, -5.0908e+00],
#         [-1.9314e+01, -1.1988e+00, -7.3756e-01,  ..., -6.8714e-01,
#          -1.9661e+00, -5.0908e+00],
#         [-1.9314e+01, -1.1988e+00, -7.3756e-01,  ..., -6.8714e-01,
#          -1.9661e+00, -5.0908e+00],
#         ...,
#         [ 6.8166e+00,  1.6405e+00,  6.2407e-02,  ...,  1.9995e+00,
#           1.9579e-01, -1.7087e-01],
#         [-1.2844e+01,  1.6422e+00, -6.8042e-01,  ...,  2.0035e+00,
#           1.6400e-01, -1.2167e-01],
#         [-1.2844e+01,  1.6438e+00,  5.2668e-03,  ...,  2.0082e+00,
#           1.9579e-01, -1.2167e-01]]) torch.Size([574, 11])
# epoch: 1
# tensor([[-1.7551e-01, -1.5157e-01, -1.2358e-01,  ..., -2.0265e-01,
#           3.4110e-02,  4.6173e-02],
#         [-2.6203e-01, -1.9953e-01, -1.3944e-01,  ..., -2.0705e-01,
#           7.8980e-03,  1.0192e-01],
#         [-2.7853e-01, -2.1641e-01, -1.3183e-01,  ..., -2.0952e-01,
#           1.7074e-04,  1.0742e-01],
#         ...,
#         [ 8.5276e-01,  4.2148e-01, -4.0841e-02,  ..., -1.2916e-02,
#           2.6010e-01,  1.7749e-02],
#         [ 7.3137e-01,  5.0582e-01, -4.7769e-02,  ..., -6.1120e-02,
#           2.1588e-01, -5.5595e-02],
#         [ 5.1572e-02, -2.2088e-02, -2.2594e-01,  ..., -1.8619e-01,
#           2.2827e-01,  3.1644e-02]], grad_fn=<SqueezeBackward0>) torch.Size([574, 11])
# tensor([[-1.9314e+01, -1.1988e+00, -7.3756e-01,  ..., -6.8714e-01,
#          -1.9661e+00, -5.0908e+00],
#         [-1.9314e+01, -1.1988e+00, -7.3756e-01,  ..., -6.8714e-01,
#          -1.9661e+00, -5.0908e+00],
#         [-1.9314e+01, -1.1988e+00, -7.3756e-01,  ..., -6.8714e-01,
#          -1.9661e+00, -5.0908e+00],
#         ...,
#         [ 6.8166e+00,  1.6405e+00,  6.2407e-02,  ...,  1.9995e+00,
#           1.9579e-01, -1.7087e-01],
#         [-1.2844e+01,  1.6422e+00, -6.8042e-01,  ...,  2.0035e+00,
#           1.6400e-01, -1.2167e-01],
#         [-1.2844e+01,  1.6438e+00,  5.2668e-03,  ...,  2.0082e+00,
#           1.9579e-01, -1.2167e-01]]) torch.Size([574, 11])
# epoch: 2
# tensor([[-3.9790e-01, -1.5408e-01, -1.2378e-01,  ..., -2.1847e-01,
#           1.6511e-02,  3.8507e-02],
#         [-5.3771e-01, -2.0414e-01, -1.3707e-01,  ..., -2.3106e-01,
#          -1.7698e-02,  8.9029e-02],
#         [-5.6733e-01, -2.2147e-01, -1.2732e-01,  ..., -2.3746e-01,
#          -2.9795e-02,  9.0950e-02],
#         ...,
#         [ 1.5458e+00,  4.3882e-01, -8.9177e-03,  ..., -4.2878e-02,
#           2.3255e-01,  5.0136e-02],
#         [ 1.2733e+00,  5.3217e-01,  6.8955e-04,  ..., -5.0045e-02,
#           2.0483e-01, -4.3975e-02],
#         [ 7.4363e-04, -2.3306e-02, -2.1845e-01,  ..., -2.1762e-01,
#           2.0233e-01,  8.1294e-03]], grad_fn=<SqueezeBackward0>) torch.Size([574, 11])
# tensor([[-1.9314e+01, -1.1988e+00, -7.3756e-01,  ..., -6.8714e-01,
#          -1.9661e+00, -5.0908e+00],
#         [-1.9314e+01, -1.1988e+00, -7.3756e-01,  ..., -6.8714e-01,
#          -1.9661e+00, -5.0908e+00],
#         [-1.9314e+01, -1.1988e+00, -7.3756e-01,  ..., -6.8714e-01,
#          -1.9661e+00, -5.0908e+00],
#         ...,
#         [ 6.8166e+00,  1.6405e+00,  6.2407e-02,  ...,  1.9995e+00,
#           1.9579e-01, -1.7087e-01],
#         [-1.2844e+01,  1.6422e+00, -6.8042e-01,  ...,  2.0035e+00,
#           1.6400e-01, -1.2167e-01],
#         [-1.2844e+01,  1.6438e+00,  5.2668e-03,  ...,  2.0082e+00,
#           1.9579e-01, -1.2167e-01]]) torch.Size([574, 11])
# epoch: 3
# tensor([[-0.6393, -0.1629, -0.1178,  ..., -0.2223,  0.0076,  0.0306],
#         [-0.8406, -0.2187, -0.1235,  ..., -0.2392, -0.0304,  0.0756],
#         [-0.8872, -0.2402, -0.1081,  ..., -0.2471, -0.0437,  0.0742],
#         ...,
#         [ 2.2488,  0.4596,  0.0619,  ..., -0.0411,  0.2157,  0.0369],
#         [ 1.8301,  0.5473,  0.0364,  ..., -0.0490,  0.2108, -0.0473],
#         [-0.0737, -0.0423, -0.2005,  ..., -0.2143,  0.2048, -0.0145]],
#        grad_fn=<SqueezeBackward0>) torch.Size([574, 11])
# tensor([[-1.9314e+01, -1.1988e+00, -7.3756e-01,  ..., -6.8714e-01,
#          -1.9661e+00, -5.0908e+00],
#         [-1.9314e+01, -1.1988e+00, -7.3756e-01,  ..., -6.8714e-01,
#          -1.9661e+00, -5.0908e+00],
#         [-1.9314e+01, -1.1988e+00, -7.3756e-01,  ..., -6.8714e-01,
#          -1.9661e+00, -5.0908e+00],
#         ...,
#         [ 6.8166e+00,  1.6405e+00,  6.2407e-02,  ...,  1.9995e+00,
#           1.9579e-01, -1.7087e-01],
#         [-1.2844e+01,  1.6422e+00, -6.8042e-01,  ...,  2.0035e+00,
#           1.6400e-01, -1.2167e-01],
#         [-1.2844e+01,  1.6438e+00,  5.2668e-03,  ...,  2.0082e+00,
#           1.9579e-01, -1.2167e-01]]) torch.Size([574, 11])
# epoch: 4
# tensor([[-0.9039, -0.1772, -0.0987,  ..., -0.2269, -0.0055,  0.0167],
#         [-1.1873, -0.2449, -0.0857,  ..., -0.2501, -0.0473,  0.0498],
#         [-1.2638, -0.2760, -0.0570,  ..., -0.2589, -0.0606,  0.0423],
#         ...,
#         [ 3.0244,  0.5232,  0.1724,  ..., -0.0683,  0.1469,  0.0121],
#         [ 2.4237,  0.5732,  0.0895,  ..., -0.0607,  0.2009, -0.0616],
#         [-0.1784, -0.0937, -0.1715,  ..., -0.2040,  0.2239, -0.0465]],
#        grad_fn=<SqueezeBackward0>) torch.Size([574, 11])
# tensor([[-1.9314e+01, -1.1988e+00, -7.3756e-01,  ..., -6.8714e-01,
#          -1.9661e+00, -5.0908e+00],
#         [-1.9314e+01, -1.1988e+00, -7.3756e-01,  ..., -6.8714e-01,
#          -1.9661e+00, -5.0908e+00],
#         [-1.9314e+01, -1.1988e+00, -7.3756e-01,  ..., -6.8714e-01,
#          -1.9661e+00, -5.0908e+00],
#         ...,
#         [ 6.8166e+00,  1.6405e+00,  6.2407e-02,  ...,  1.9995e+00,
#           1.9579e-01, -1.7087e-01],
#         [-1.2844e+01,  1.6422e+00, -6.8042e-01,  ...,  2.0035e+00,
#           1.6400e-01, -1.2167e-01],
#         [-1.2844e+01,  1.6438e+00,  5.2668e-03,  ...,  2.0082e+00,
#           1.9579e-01, -1.2167e-01]]) torch.Size([574, 11])
# epoch: 5
# tensor([[-1.2217e+00, -1.9994e-01, -8.3183e-02,  ..., -2.3168e-01,
#          -1.6047e-02, -3.8086e-04],
#         [-1.6300e+00, -2.7719e-01, -4.5233e-02,  ..., -2.6575e-01,
#          -6.4438e-02,  1.5293e-02],
#         [-1.7601e+00, -3.1540e-01, -2.0768e-04,  ..., -2.7610e-01,
#          -7.9285e-02,  2.0447e-04],
#         ...,
#         [ 3.8421e+00,  5.4084e-01,  2.6963e-01,  ..., -1.0287e-01,
#           1.2219e-01, -1.6719e-02],
#         [ 3.0671e+00,  5.7117e-01,  1.4115e-01,  ..., -8.3460e-02,
#           1.8915e-01, -8.4191e-02],
#         [-2.5018e-01, -1.0866e-01, -1.4165e-01,  ..., -1.9489e-01,
#           2.0654e-01, -7.7358e-02]], grad_fn=<SqueezeBackward0>) torch.Size([574, 11])
# tensor([[-1.9314e+01, -1.1988e+00, -7.3756e-01,  ..., -6.8714e-01,
#          -1.9661e+00, -5.0908e+00],
#         [-1.9314e+01, -1.1988e+00, -7.3756e-01,  ..., -6.8714e-01,
#          -1.9661e+00, -5.0908e+00],
#         [-1.9314e+01, -1.1988e+00, -7.3756e-01,  ..., -6.8714e-01,
#          -1.9661e+00, -5.0908e+00],
#         ...,
#         [ 6.8166e+00,  1.6405e+00,  6.2407e-02,  ...,  1.9995e+00,
#           1.9579e-01, -1.7087e-01],
#         [-1.2844e+01,  1.6422e+00, -6.8042e-01,  ...,  2.0035e+00,
#           1.6400e-01, -1.2167e-01],
#         [-1.2844e+01,  1.6438e+00,  5.2668e-03,  ...,  2.0082e+00,
#           1.9579e-01, -1.2167e-01]]) torch.Size([574, 11])
# epoch: 6
# tensor([[-1.6373, -0.2300, -0.0809,  ..., -0.2366, -0.0246, -0.0200],
#         [-2.2220, -0.3112, -0.0186,  ..., -0.2817, -0.0835, -0.0227],
#         [-2.4342, -0.3508,  0.0419,  ..., -0.2915, -0.1021, -0.0441],
#         ...,
#         [ 4.7010,  0.5088,  0.2377,  ..., -0.1387,  0.2440, -0.0719],
#         [ 3.7380,  0.5391,  0.1300,  ..., -0.1061,  0.2411, -0.1157],
#         [-0.2927, -0.1044, -0.0960,  ..., -0.1696,  0.1357, -0.0980]],
#        grad_fn=<SqueezeBackward0>) torch.Size([574, 11])
# tensor([[-1.9314e+01, -1.1988e+00, -7.3756e-01,  ..., -6.8714e-01,
#          -1.9661e+00, -5.0908e+00],
#         [-1.9314e+01, -1.1988e+00, -7.3756e-01,  ..., -6.8714e-01,
#          -1.9661e+00, -5.0908e+00],
#         [-1.9314e+01, -1.1988e+00, -7.3756e-01,  ..., -6.8714e-01,
#          -1.9661e+00, -5.0908e+00],
#         ...,
#         [ 6.8166e+00,  1.6405e+00,  6.2407e-02,  ...,  1.9995e+00,
#           1.9579e-01, -1.7087e-01],
#         [-1.2844e+01,  1.6422e+00, -6.8042e-01,  ...,  2.0035e+00,
#           1.6400e-01, -1.2167e-01],
#         [-1.2844e+01,  1.6438e+00,  5.2668e-03,  ...,  2.0082e+00,
#           1.9579e-01, -1.2167e-01]]) torch.Size([574, 11])
# epoch: 7
# tensor([[-2.2493, -0.2812, -0.0956,  ..., -0.2472, -0.0395, -0.0426],
#         [-3.0250, -0.3707, -0.0220,  ..., -0.2952, -0.1102, -0.0673],
#         [-3.3106, -0.4141,  0.0421,  ..., -0.2987, -0.1284, -0.0994],
#         ...,
#         [ 5.2761,  0.4333,  0.2530,  ..., -0.1300,  0.2462, -0.1087],
#         [ 4.2674,  0.4820,  0.1488,  ..., -0.1010,  0.2388, -0.1415],
#         [-0.3355, -0.0628, -0.0740,  ..., -0.1538,  0.0899, -0.1241]],
#        grad_fn=<SqueezeBackward0>) torch.Size([574, 11])
# tensor([[-1.9314e+01, -1.1988e+00, -7.3756e-01,  ..., -6.8714e-01,
#          -1.9661e+00, -5.0908e+00],
#         [-1.9314e+01, -1.1988e+00, -7.3756e-01,  ..., -6.8714e-01,
#          -1.9661e+00, -5.0908e+00],
#         [-1.9314e+01, -1.1988e+00, -7.3756e-01,  ..., -6.8714e-01,
#          -1.9661e+00, -5.0908e+00],
#         ...,
#         [ 6.8166e+00,  1.6405e+00,  6.2407e-02,  ...,  1.9995e+00,
#           1.9579e-01, -1.7087e-01],
#         [-1.2844e+01,  1.6422e+00, -6.8042e-01,  ...,  2.0035e+00,
#           1.6400e-01, -1.2167e-01],
#         [-1.2844e+01,  1.6438e+00,  5.2668e-03,  ...,  2.0082e+00,
#           1.9579e-01, -1.2167e-01]]) torch.Size([574, 11])
# epoch: 8
# tensor([[-2.5978, -0.2920, -0.1407,  ..., -0.2618, -0.0176, -0.0546],
#         [-3.4731, -0.3745, -0.0736,  ..., -0.3193, -0.0886, -0.0852],
#         [-3.8137, -0.4149, -0.0100,  ..., -0.3247, -0.1086, -0.1139],
#         ...,
#         [ 6.0970,  0.4133,  0.2176,  ..., -0.1615,  0.3077, -0.1033],
#         [ 4.9351,  0.4650,  0.1223,  ..., -0.1095,  0.2866, -0.1434],
#         [-0.2058, -0.0483, -0.0901,  ..., -0.1370,  0.1000, -0.1798]],
#        grad_fn=<SqueezeBackward0>) torch.Size([574, 11])
# tensor([[-1.9314e+01, -1.1988e+00, -7.3756e-01,  ..., -6.8714e-01,
#          -1.9661e+00, -5.0908e+00],
#         [-1.9314e+01, -1.1988e+00, -7.3756e-01,  ..., -6.8714e-01,
#          -1.9661e+00, -5.0908e+00],
#         [-1.9314e+01, -1.1988e+00, -7.3756e-01,  ..., -6.8714e-01,
#          -1.9661e+00, -5.0908e+00],
#         ...,
#         [ 6.8166e+00,  1.6405e+00,  6.2407e-02,  ...,  1.9995e+00,
#           1.9579e-01, -1.7087e-01],
#         [-1.2844e+01,  1.6422e+00, -6.8042e-01,  ...,  2.0035e+00,
#           1.6400e-01, -1.2167e-01],
#         [-1.2844e+01,  1.6438e+00,  5.2668e-03,  ...,  2.0082e+00,
#           1.9579e-01, -1.2167e-01]]) torch.Size([574, 11])
# epoch:
],
#        grad_fn=<SqueezeBackward0>) torch.Size([574, 11])
# tensor([[-1.9314e+01, -1.1988e+00, -7.3756e-01,  ..., -6.8714e-01,
#          -1.9661e+00, -5.0908e+00],
#         [-1.9314e+01, -1.1988e+00, -7.3756e-01,  ..., -6.8714e-01,
#          -1.9661e+00, -5.0908e+00],
#         [-1.9314e+01, -1.1988e+00, -7.3756e-01,  ..., -6.8714e-01,
#          -1.9661e+00, -5.0908e+00],
#         ...,
#         [ 6.8166e+00,  1.6405e+00,  6.2407e-02,  ...,  1.9995e+00,
#           1.9579e-01, -1.7087e-01],
#         [-1.2844e+01,  1.6422e+00, -6.8042e-01,  ...,  2.0035e+00,
#           1.6400e-01, -1.2167e-01],
#         [-1.2844e+01,  1.6438e+00,  5.2668e-03,  ...,  2.0082e+00,
#           1.9579e-01, -1.2167e-01]]) torch.Size([574, 11])
# epoch: 18
# tensor([[-3.8290e+00, -2.0257e-01, -3.8498e-02,  ..., -2.8294e-01,
#          -1.6635e-01, -4.7314e-02],
#         [-5.7097e+00, -2.8594e-01, -1.7458e-02,  ..., -3.4668e-01,
#          -2.9244e-01, -5.3943e-02],
#         [-6.5004e+00, -3.2530e-01, -7.8644e-03,  ..., -3.3364e-01,
#          -3.4285e-01, -4.9706e-02],
#         ...,
#         [ 1.0843e+01,  4.7278e-01,  7.0354e-01,  ...,  3.4501e-01,
#           3.7050e-01, -1.3679e-01],
#         [ 9.7527e+00,  5.2265e-01,  5.3574e-01,  ...,  2.9072e-01,
#           4.0731e-01, -1.4200e-01],
#         [ 4.7722e-01, -1.6569e-01,  2.5384e-02,  ..., -3.8819e-01,
#           1.5020e-01, -2.0424e-01]], grad_fn=<SqueezeBackward0>) torch.Size([574, 11])
# tensor([[-1.9314e+01, -1.1988e+00, -7.3756e-01,  ..., -6.8714e-01,
#          -1.9661e+00, -5.0908e+00],
#         [-1.9314e+01, -1.1988e+00, -7.3756e-01,  ..., -6.8714e-01,
#          -1.9661e+00, -5.0908e+00],
#         [-1.9314e+01, -1.1988e+00, -7.3756e-01,  ..., -6.8714e-01,
#          -1.9661e+00, -5.0908e+00],
#         ...,
#         [ 6.8166e+00,  1.6405e+00,  6.2407e-02,  ...,  1.9995e+00,
#           1.9579e-01, -1.7087e-01],
#         [-1.2844e+01,  1.6422e+00, -6.8042e-01,  ...,  2.0035e+00,
#           1.6400e-01, -1.2167e-01],
#         [-1.2844e+01,  1.6438e+00,  5.2668e-03,  ...,  2.0082e+00,
#           1.9579e-01, -1.2167e-01]]) torch.Size([574, 11])
# epoch: 19
# tensor([[-3.7305, -0.2300, -0.0836,  ..., -0.2799, -0.1073, -0.0653],
#         [-5.6226, -0.3246, -0.0778,  ..., -0.3508, -0.2085, -0.0767],
#         [-6.4575, -0.3680, -0.0748,  ..., -0.3427, -0.2531, -0.0783],
#         ...,
#         [10.9964,  0.4394,  0.6690,  ...,  0.3826,  0.4419, -0.2326],
#         [10.1240,  0.5200,  0.4962,  ...,  0.2908,  0.4702, -0.1755],
#         [ 0.5630, -0.1638,  0.0521,  ..., -0.3761,  0.0906, -0.2246]],
#        grad_fn=<SqueezeBackward0>) torch.Size([574, 11])
# tensor([[-1.9314e+01, -1.1988e+00, -7.3756e-01,  ..., -6.8714e-01,
#          -1.9661e+00, -5.0908e+00],
#         [-1.9314e+01, -1.1988e+00, -7.3756e-01,  ..., -6.8714e-01,
#          -1.9661e+00, -5.0908e+00],
#         [-1.9314e+01, -1.1988e+00, -7.3756e-01,  ..., -6.8714e-01,
#          -1.9661e+00, -5.0908e+00],
#         ...,
#         [ 6.8166e+00,  1.6405e+00,  6.2407e-02,  ...,  1.9995e+00,
#           1.9579e-01, -1.7087e-01],
#         [-1.2844e+01,  1.6422e+00, -6.8042e-01,  ...,  2.0035e+00,
#           1.6400e-01, -1.2167e-01],
#         [-1.2844e+01,  1.6438e+00,  5.2668e-03,  ...,  2.0082e+00,
#           1.9579e-01, -1.2167e-01]]) torch.Size([574, 11])

# %%
with torch.no_grad():
    X2 = model.suit4model(X)
    Y_preds = model(X2)
    print(Y_preds, Y_preds.shape)
    print(Y, Y.shape)
# Out:
# tensor([[[-3.7334e+00, -1.7664e-01, -1.0524e-01,  ..., -2.3294e-01,
#           -7.2634e-02, -5.8651e-03]],
#
#         [[-5.7286e+00, -2.5873e-01, -1.0197e-01,  ..., -3.0361e-01,
#           -1.6481e-01, -6.2650e-04]],
#
#         [[-6.5684e+00, -2.9846e-01, -8.6847e-02,  ..., -3.0824e-01,
#           -1.9991e-01, -3.3516e-03]],
#
#         ...,
#
#         [[ 1.2581e+01,  3.8867e-01,  4.1738e-01,  ...,  1.5467e-01,
#            5.0298e-01, -1.2846e-02]],
#
#         [[ 1.1682e+01,  5.1085e-01,  2.8700e-01,  ...,  1.1825e-01,
#            5.7324e-01,  3.2953e-02]],
#
#         [[ 1.0016e+00, -1.0404e-01, -2.9470e-02,  ..., -3.1303e-01,
#            1.0368e-01, -1.4906e-01]]]) torch.Size([574, 1, 11])
# tensor([[-1.9314e+01, -1.1988e+00, -7.3756e-01,  ..., -6.8714e-01,
#          -1.9661e+00, -5.0908e+00],
#         [-1.9314e+01, -1.1988e+00, -7.3756e-01,  ..., -6.8714e-01,
#          -1.9661e+00, -5.0908e+00],
#         [-1.9314e+01, -1.1988e+00, -7.3756e-01,  ..., -6.8714e-01,
#          -1.9661e+00, -5.0908e+00],
#         ...,
#         [ 6.8166e+00,  1.6405e+00,  6.2407e-02,  ...,  1.9995e+00,
#           1.9579e-01, -1.7087e-01],
#         [-1.2844e+01,  1.6422e+00, -6.8042e-01,  ...,  2.0035e+00,
#           1.6400e-01, -1.2167e-01],
#         [-1.2844e+01,  1.6438e+00,  5.2668e-03,  ...,  2.0082e+00,
#           1.9579e-01, -1.2167e-01]]) torch.Size([574, 11])

# %%
Y_preds_numpy = Y_preds.squeeze()
Y_preds_numpy = Y_preds_numpy.numpy()
output = pd.DataFrame(Y_preds_numpy, columns=data_columns)
output
type(output)
denorm_output = output*data_std + data_mean

# %%
compare_df = pd.DataFrame([denorm_output['actuals.newCases'], data['actuals.newCases'].reset_index(drop=True)]).transpose()
compare_df.columns = ['preds', 'real']
compare_df.plot()
compare_df
# Out:
#            preds    real
# 0     929.567191     0.0
# 1     810.525924     0.0
# 2     760.423090     0.0
# 3     737.173573     0.0
# 4     724.044906     0.0
# ..           ...     ...
# 570  1704.587290  1311.0
# 571  1902.944026  2428.0
# 572  1849.302940  1559.0
# 573  1212.065349   386.0
# 574          NaN   386.0
#
# [575 rows x 2 columns]

# %% [markdown]
# # Performance eval
# ## train

# %%
preds = denorm_output['actuals.newCases'].to_numpy()
reals = data['actuals.newCases'].to_numpy()[1:]

# %%
RMSE_train = np.sqrt(np.sum(np.square(preds - reals))/preds.shape)
MAE_train = np.sum(np.abs(preds - reals))/preds.shape

# %%
print('RMSE_train', RMSE_train, 'MAE_train', MAE_train)
# Out:
# RMSE_train [822.20671454] MAE_train [538.9582025]

# %% [markdown]
# ## test

# %%
days = data_test.shape[0]
prev_days = data.shape[0]-1

X = X[-prev_days:]
print(X.shape)

for day in range(days):
    with torch.no_grad():
        X2 = model.suit4model(X)
        Y_preds = model(X2).squeeze()
        X[:prev_days-1] = X[1:prev_days].clone()
        X[prev_days-1] = Y_preds[-1]

Y_preds = X[-days:]
# Out:
# torch.Size([574, 11])

# %%
Y_preds_numpy = Y_preds.squeeze()
Y_preds_numpy = Y_preds_numpy.numpy()
output = pd.DataFrame(Y_preds_numpy, columns=data_columns)
output
type(output)
denorm_output = output*data_std + data_mean

# %%
denorm_output
# Out:
#    actuals.newCases  actuals.cases  actuals.newDeaths  actuals.deaths  \
# 0       1212.065349  256026.994875          12.392083     4577.054093
# 1       1247.329620  261760.813474           9.893654     4746.816833
# 2       1376.343126  304311.941729          11.548220     4896.396873
# 3       1627.251372  355099.131215          15.812818     5181.595207
# 4       1850.709808  383227.954647          19.422155     5376.604281
# 5       1947.744986  388615.954935          20.883546     5426.859770
# 6       1989.833830  391954.480833          21.510209     5423.863500
# 7       2014.821478  395236.608897          21.903742     5410.958849
# 8       2033.062120  398159.434258          22.198277     5398.103380
# 9       2047.466505  400637.412302          22.433809     5386.485035
#
#    actuals.positiveTests  actuals.negativeTests  actuals.vaccinesDistributed  \
# 0          275157.326764           3.092126e+06                 1.343444e+06
# 1          308393.769719           2.972132e+06                 1.557755e+06
# 2          323159.548164           3.191427e+06                 1.785371e+06
# 3          373604.875128           3.588651e+06                 1.764974e+06
# 4          427918.835401           3.906455e+06                 1.636088e+06
# 5          447970.080924           4.048353e+06                 1.610221e+06
# 6          452370.063606           4.149173e+06                 1.619802e+06
# 7          453388.647178           4.230458e+06                 1.632824e+06
# 8          453736.997126           4.296900e+06                 1.645352e+06
# 9          453928.007198           4.351470e+06                 1.657272e+06
#
#    actuals.vaccinationsInitiated  actuals.vaccinationsCompleted  \
# 0                   1.288306e+06                  472736.870568
# 1                   1.443773e+06                  830014.158459
# 2                   1.353677e+06                  788172.389106
# 3                   1.332795e+06                  818843.880065
# 4                   1.349198e+06                  851516.839158
# 5                   1.297451e+06                  826465.990261
# 6                   1.234118e+06                  794302.098569
# 7                   1.181087e+06                  767055.443129
# 8                   1.138153e+06                  743937.560948
# 9                   1.103049e+06                  724004.194442
#
#    metrics.testPositivityRatio  metrics.infectionRate
# 0                     0.065103               1.004433
# 1                     0.065239               1.013129
# 2                     0.065126               1.012776
# 3                     0.068818               1.022535
# 4                     0.074088               1.026911
# 5                     0.075740               1.023139
# 6                     0.076005               1.020407
# 7                     0.076038               1.018584
# 8                     0.076038               1.017196
# 9                     0.076026               1.016053

# %%
data_test
# Out:
#       actuals.newCases  actuals.cases  actuals.newDeaths  actuals.deaths  \
# 3696             386.0       664396.0                1.0          7649.0
# 3697             386.0       664782.0               13.0          7662.0
# 3698            3853.0       668635.0               21.0          7683.0
# 3699            2297.0       670932.0               20.0          7703.0
# 3700            1384.0       672316.0               14.0          7717.0
# 3701            2531.0       674847.0               14.0          7731.0
# 3702            2296.0       677143.0               41.0          7772.0
# 3703             451.0       677594.0                4.0          7776.0
# 3704             416.0       678010.0                6.0          7782.0
# 3705            3902.0       681912.0               23.0          7805.0
#
#       actuals.positiveTests  actuals.negativeTests  \
# 3696               668384.0              9333946.0
# 3697               669566.0              9347759.0
# 3698               671260.0              9364745.0
# 3699               673317.0              9391411.0
# 3700               676415.0              9426207.0
# 3701               678741.0              9456574.0
# 3702               681087.0              9486980.0
# 3703               683134.0              9513288.0
# 3704               684520.0              9528864.0
# 3705               686303.0              9544931.0
#
#       actuals.vaccinesDistributed  actuals.vaccinationsInitiated  \
# 3696                    8109865.0                      3759587.0
# 3697                    8109725.0                      3764748.0
# 3698                    8109725.0                      3767056.0
# 3699                    8110245.0                      3769431.0
# 3700                    8127615.0                      3773179.0
# 3701                    8145395.0                      3777400.0
# 3702                    8216005.0                      3780734.0
# 3703                    8230095.0                      3784978.0
# 3704                    8227015.0                      3792361.0
# 3705                    8226595.0                      3794362.0
#
#       actuals.vaccinationsCompleted  metrics.testPositivityRatio  \
# 3696                      3399977.0                        0.067
# 3697                      3405927.0                        0.068
# 3698                      3408864.0                        0.068
# 3699                      3411538.0                        0.069
# 3700                      3415476.0                        0.073
# 3701                      3419720.0                        0.074
# 3702                      3423369.0                        0.077
# 3703                      3428116.0                        0.076
# 3704                      3437414.0                        0.076
# 3705                      3439988.0                        0.077
#
#       metrics.infectionRate
# 3696                   1.01
# 3697                   1.01
# 3698                   1.02
# 3699                   1.03
# 3700                   1.03
# 3701                   1.04
# 3702                   1.05
# 3703                   1.05
# 3704                   1.06
# 3705                   1.06

# %%
compare_df = pd.DataFrame([denorm_output['actuals.newCases'], data_test['actuals.newCases'].reset_index(drop=True)]).transpose()
compare_df.columns = ['preds', 'real']
compare_df.plot()
# Out:
# <AxesSubplot:>

# %%
preds = denorm_output['actuals.newCases'].to_numpy()
reals = data_test['actuals.newCases'].to_numpy()

# %%
RMSE_train = np.sqrt(np.sum(np.square(preds - reals))/preds.shape)
MAE_train = np.sum(np.abs(preds - reals))/preds.shape

# %%
print('RMSE_train', RMSE_train, 'MAE_train', MAE_train)
# Out:
# RMSE_train [1309.89042861] MAE_train [1122.53485559]
